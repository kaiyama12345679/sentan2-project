# %%
import pandas as pd
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F



df1 = pd.read_csv("./datas/good.csv")
df1["label"] = 0
df2 = pd.read_csv("./datas/bad.csv")
df2["label"] = 1
# df3 = pd.read_csv(args.f3)
# df3["label"] = 2
# df4 = pd.read_csv(args.f4)
# df4["label"] = 3

df2.head()
# Out:
#         0_x       0_y       1_x       1_y       2_x       2_y       3_x  \
# 0  0.795720  0.973323  0.719086  1.067874  0.638652  1.098942  0.586370
# 1  0.796238  0.995219  0.725329  1.088984  0.646547  1.119954  0.592963
# 2  0.788603  0.960922  0.712697  1.078838  0.624698  1.126765  0.565577
# 3  0.795190  0.902384  0.717420  1.028491  0.617910  1.069717  0.550245
# 4  0.780226  0.855231  0.711336  0.995824  0.610175  1.054990  0.540806
#
#         3_y       4_x       4_y  ...      16_y      17_x      17_y      18_x  \
# 0  1.092170  0.555111  1.072784  ...  1.032914  0.611480  0.828981  0.614860
# 1  1.118312  0.556344  1.098352  ...  0.959648  0.609576  0.771090  0.603115
# 2  1.136794  0.523424  1.134511  ...  0.921833  0.598138  0.720166  0.590722
# 3  1.047697  0.518431  0.982790  ...  0.854002  0.595074  0.675002  0.589211
# 4  1.048779  0.500825  1.023977  ...  0.812169  0.583072  0.634806  0.582005
#
#        18_y      19_x      19_y      20_x      20_y  label
# 0  0.959955  0.653550  0.993026  0.673571  0.984184      1
# 1  0.896344  0.647506  0.930812  0.668803  0.904458      1
# 2  0.835277  0.640501  0.866394  0.656637  0.838509      1
# 3  0.782189  0.637501  0.817979  0.647226  0.787865      1
# 4  0.738984  0.630749  0.774154  0.638871  0.743684      1
#
# [5 rows x 43 columns]

# %%
merged_df = pd.concat([df1, df2], axis=0, ignore_index=True)
